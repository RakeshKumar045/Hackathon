# %%
from keras.preprocessing.image import ImageDataGenerator

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense

from keras.preprocessing.image import load_img, img_to_array , load_img

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(128, 128, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# the model so far outputs 3D feature maps (height, width, features)




model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
batch_size = 16

# train_datagen = ImageDataGenerator( rotation_range=40, width_shift_range=0.2,height_shift_range=0.2,
#         rescale=1. / 255,shear_range=0.2,zoom_range=0.2, horizontal_flip=True,fill_mode='nearest')



# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator( rescale=1. / 255, shear_range=0.2,zoom_range=0.2,horizontal_flip=True)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

# this is a generator that will read pictures found in
# subfolers of 'data/train', and indefinitely generate
# batches of augmented image data
train_dataset = train_datagen.flow_from_directory(
    'cats_dogs/train',  # this is the target directory
    target_size=(128, 128),  # all images will be resized to 150x150
    batch_size=batch_size,
    class_mode='binary')  # since we use binary_crossentropy loss, we need binary labels

# this is a similar generator, for validation data
validation_dataset = test_datagen.flow_from_directory(
    'cats_dogs/validation',
    target_size=(128, 128),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 32 images belonging to 2 classes.
# Found 8 images belonging to 2 classes.

# %%
model.fit_generator( train_dataset, steps_per_epoch=2000 // batch_size, epochs=5,
    validation_data=validation_dataset, validation_steps=800 // batch_size)
# Out:
# Epoch 1/5
# 125/125 [==============================] - 40s 318ms/step - loss: 0.5097 - accuracy: 0.7385 - val_loss: 0.2444 - val_accuracy: 1.0000
# Epoch 2/5
# 125/125 [==============================] - 40s 322ms/step - loss: 0.0892 - accuracy: 0.9755 - val_loss: 0.1142 - val_accuracy: 0.8750
# Epoch 3/5
# 125/125 [==============================] - 35s 279ms/step - loss: 0.0387 - accuracy: 0.9900 - val_loss: 0.3906 - val_accuracy: 0.8750
# Epoch 4/5
# 125/125 [==============================] - 35s 282ms/step - loss: 0.0241 - accuracy: 0.9945 - val_loss: 0.4973 - val_accuracy: 0.8750
# Epoch 5/5
# 125/125 [==============================] - 34s 269ms/step - loss: 0.0802 - accuracy: 0.9920 - val_loss: 0.5347 - val_accuracy: 0.8750

# %%
model.save_weights('cat_dog_model_128.h5')  # always save your weights after training or during training
model.save("cat_dog_model_128.h5")

# %%
img = load_img('test_dog2.jpg')  # this is a PIL image
x = img_to_array(img.resize([128, 128]))  # this is a Numpy array with shape (3, 150, 150)
x = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode= RGB size=1024x576 at 0x7F13E463D890>

# %%
if (model.predict_classes(x) == 1):
    print("It is a DOG")
else:
    print("It is a Cat")
# Out:
# It is a DOG

# %%
model.predict_classes(x)
# Out:
# array([[1]], dtype=int32)
