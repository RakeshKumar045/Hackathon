# %%
from keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array
# Out:
# Using TensorFlow backend.

# %%
model = load_model("cat_dog_model_128.h5")

img = load_img('test_cat1.jpg')  # this is a PIL image
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode= RGB size=275x183 at 0x7FDAF04B8C50>

# %%
x = img_to_array(img.resize([128, 128]))  # this is a Numpy array with shape (3, 150, 150)
x = x.reshape((1,) + x.shape)

if (model.predict_classes(x) == 1):
    print("It is a DOG")
else:
    print("It is a Cat")
# Out:
# It is a Cat
