# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/lgb-sol/lgb_annual.csv
# /kaggle/input/predictions-av-bank-data/xgb_annual.csv
# /kaggle/input/predictions-av-bank-data/cat_annual.csv

# %%
xgb_preds = pd.read_csv('/kaggle/input/predictions-av-bank-data/xgb_annual.csv')
cat_preds = pd.read_csv('/kaggle/input/predictions-av-bank-data/cat_annual.csv')
lgb_preds = pd.read_csv('/kaggle/input/lgb-sol/lgb_annual.csv')

final_preds = pd.DataFrame(columns = xgb_preds.columns)
final_preds
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Interest_Rate]
# Index: []

# %%
final_preds['Loan_ID'] = xgb_preds['Loan_ID']
x = pd.concat([xgb_preds['Interest_Rate'], cat_preds['Interest_Rate'], lgb_preds['Interest_Rate']], axis = 1)

# %%
final_preds['Interest_Rate'] = np.median(x, axis = 1)
final_preds
# Out:
#          Loan_ID  Interest_Rate
# 0       10164310            1.0
# 1       10164311            1.0
# 2       10164312            2.0
# 3       10164313            2.0
# 4       10164314            2.0
# ...          ...            ...
# 109536  10273846            3.0
# 109537  10273847            1.0
# 109538  10273848            2.0
# 109539  10273849            3.0
# 109540  10273850            2.0
#
# [109541 rows x 2 columns]

# %%
final_preds.Interest_Rate.value_counts()
# Out:
# 2.0    53444
# 3.0    40066
# 1.0    16031
# Name: Interest_Rate, dtype: int64

# %%
final_preds.to_csv('final_ensemble.csv', index = False)
